# %% [markdown]
# # గ్రోయింగ్ డిగ్రీ డేస్
#
# ఈ నోట్‌బుక్ ఒక CSV ఫైల్‌లో సేవ్ చేసిన ఉష్ణోగ్రత డేటాను లోడ్ చేస్తుంది, మరియు దాన్ని విశ్లేషిస్తుంది. ఇది ఉష్ణోగ్రతలను చిత్రీకరిస్తుంది, ప్రతి日の గరిష్ఠ మరియు కనిష్ఠ విలువను చూపిస్తుంది, మరియు GDDని లెక్కిస్తుంది.
#
# ఈ నోట్‌బుక్ ఉపయోగించడానికి:
#
# * `temperature.csv` ఫైల్‌ను ఈ నోట్‌బుక్ ఉన్న అదే ఫోల్డర్లో కాపీ చేయండి
# * పైలోని **▶︎ Run** బటన్ ఉపయోగించి అన్ని సెల్స్‌ను నడపండి. ఇది ఎంచుకున్న సెల్‌ను నడిపించి, ఆ తర్వాత తరువాతటికి చేరుకుంటుంది.

# %% [markdown]
# క్రింద ఉన్న సెల్‌లో, `base_temperature` ని మొక్క యొక్క ప్రాథమిక ఉష్ణోగ్రతకు సెట్ చేయండి.

# %%
base_temperature = 10

# %% [markdown]
# CSV ఫైల్ ఇప్పుడు pandas ఉపయోగించి లోడ్ చేయాలి.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the temperature CSV file
df = pd.read_csv('temperature.csv')

# %% [markdown]
# ఇప్పుడు ఉష్మోగ్రాఫ్ మీద గ ఆర్ఖ్ చేయవచ్చు.

# %%
plt.figure(figsize=(20, 10))
plt.plot(df['date'], df['temperature'])
plt.xticks(rotation='vertical');

# %% [markdown]
# సారాంశం పూర్తయిన తర్వాత, 데이터를 `date` కాలములో ఆధారంగా సమూహపరిచినచో, ప్రతి датేపై కనిష్ట మరియు గరిష్ట ఉష్ణోగ్రతలను తీసుకునే అవకాశం ఉంటుంది.

# %%
# Convert datetimes to pure dates so we can group by the date
df['date'] = pd.to_datetime(df['date']).dt.date

# Group the data by date so it can be analyzed by date
data_by_date = df.groupby('date')

# Get the minimum and maximum temperatures for each date
min_by_date = data_by_date.min()
max_by_date = data_by_date.max()

# Join the min and max temperatures into one dataframe and flatten it
min_max_by_date = min_by_date.join(max_by_date, on='date', lsuffix='_min', rsuffix='_max')
min_max_by_date = min_max_by_date.reset_index()

# %% [markdown]
# GDD ను ప్రామాణిక GDD సమీకరణం ఉపయోగించి లెక్కించవచ్చు.

# %%
def calculate_gdd(row):
    return ((row['temperature_max'] + row['temperature_min']) / 2) - base_temperature

# Calculate the GDD for each row
min_max_by_date['gdd'] = min_max_by_date.apply (lambda row: calculate_gdd(row), axis=1)

# Print the results
print(min_max_by_date[['date', 'gdd']].to_string(index=False))

# %% [markdown]
# ---
#
# <!-- CO-OP TRANSLATOR DISCLAIMER START -->
# **సమ్మతి తప్పింపు**:
# ఈ పత్రాన్ని AI అనువాద సేవ [కో-ఆప్ ట్రాన్స్లేటర్](https://github.com/Azure/co-op-translator) ద్వారా అనువదించడం జరిగింది. మేము సరిగ్గా అనువదించే ప్రయత్నం చేసినప్పటికీ, స్వయంచాలక అనువాదాల్లో ఎర్రర్లు లేదా అస్పష్టతలు ఉండవచ్చు. మూల పత్రం దాని స్వదేశీ భాషలోనే అధికారిక వనరు గా పరిగణించాలి. కీలకమైన సమాచారం కోసం, నిపుణుల చేత అనువాదం చేయించుకోవడం మంచిది. ఈ అనువాదం ఉపయోగించడంలో కలిగే ఎటువంటి అపార్థాలు లేదా పొరపాట్ల కోసం మేము బాధ్యత తీసుకోము.
# <!-- CO-OP TRANSLATOR DISCLAIMER END -->
